# %% [markdown]
# **Practice**

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# load csv

data = pd.read_csv('linear_regression_example1.txt', delimiter=',')

# %%
print(data.head())  # Display the first few rows
print(data.info())  # Check the data types
# Out:
#           x         y
# 0  5.488135  4.115874
# 1  7.151894  6.569801
# 2  6.027634  4.783712
# 3  5.448832  4.709630
# 4  4.236548  1.644311
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       10000 non-null  float64
#  1   y       10000 non-null  float64
# dtypes: float64(2)
# memory usage: 156.4 KB
# None

# %%
x = data[['x']]  # Predictor variable
y = data['y']    # Target variable

# %%
# train model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
# view model coefficients and make predictions
print("Intercept:", model.intercept_)
print("Slope:", model.coef_[0])

y_pred = model.predict(x)
# Out:
# Intercept: 0.9582430657229755
# Slope: 0.7082719666812118

# %%
# visualize results:

plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
